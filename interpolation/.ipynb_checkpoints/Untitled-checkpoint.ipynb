# %%
# !pip install sklearn
# Out:
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/Pillow-9.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/PyYAML-6.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/numpy-1.24.2-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/Pillow-9.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/PyYAML-6.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/numpy-1.24.2-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/torch-1.13.0a0+git49444c3-py3.11.egg-info due to invalid metadata entry 'name'
# Requirement already satisfied: sklearn in /usr/local/lib/python3.11/site-packages (0.0.post1)
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/Pillow-9.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/PyYAML-6.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/numpy-1.24.2-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/torch-1.13.0a0+git49444c3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/Pillow-9.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/PyYAML-6.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/numpy-1.24.2-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/Pillow-9.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/PyYAML-6.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/numpy-1.24.2-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/Pillow-9.4.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/PyYAML-6.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/numpy-1.24.2-py3.11.egg-info due to invalid metadata entry 'name'

# %%
# !python train.py
# Out:
# Traceback (most recent call last):
#   File "/Users/78k/Desktop/test_soledge2gitr/train.py", line 2, in <module>
#     import nn_learner
#   File "/Users/78k/Desktop/test_soledge2gitr/nn_learner.py", line 11, in <module>
#     import sklearn.metrics
# ModuleNotFoundError: No module named 'sklearn'

# %%
import sklearn.metrics

# %%
# Copyright 2022, SOLEDGE contributors
# Authors: Nick Lubbers(LANL), Abdou Diaw (ORNL)
# License: 3-Clause-BSD-LBNL
"""
This file is part SOLEDGE-GITR.
It uses an ensemble of NN to train and test dataset from DB.
"""
# -------
# Imports
# -------
import copy
import warnings

import numpy as np
# Built with numpy '1.16.3'

import torch
import torch.utils.data
# Built with pytorch 1.3.1

import sklearn.metrics
# Built with sklearn 0.20.1

import sqlite3
from enum import Enum, IntEnum
import collections

torch.set_default_dtype(torch.float64)

# Define inputs/ouputs of the problem

Inputs = collections.namedtuple('Inputs', 'R Z')
Outputs = collections.namedtuple('Outputs', 'BPHI BR BZ TE NE VE TI NI VI')


def getAllGNDData(dbPath):
    selString = ""

    selString = "SELECT * FROM SOLEDGE;"
    sqlDB = sqlite3.connect(dbPath, timeout=45.0)
    sqlCursor = sqlDB.cursor()
    gndResults = []
    for row in sqlCursor.execute(selString):
        # Add row to numpy array
        gndResults.append(row)
    sqlCursor.close()
    sqlDB.close()
    return np.array(gndResults)

class Model():
    """
    Ensemble model. Error bar is std. dev. of networks.
    """
    def __init__(self,networks,err_info=None):
        self.networks = networks
        self.err_info = err_info

    def __call__(self,request_params):
        """
        :param request_params: Inputs
        :return: result[3], errbar[3]
        """
        request_params = self.pack_inputs(request_params)

        result_mean,result_error = self.process(request_params)

        result_mean = self.unpack_outputs(result_mean)
        result_error = self.unpack_outputs(result_error)
        return result_mean,result_error


    def process(self,request_params,perform_column_extraction=True): #as a numpy array
        batched = request_params.ndim>1

        request_params = torch.as_tensor(request_params)
        if perform_column_extraction:
            request_params = request_params[...,SOLVER_INDEXES["input_slice"]]

        if not batched:
            request_params = request_params.unsqueeze(0)

        results = np.asarray([np.asarray(nn(request_params)) for nn in self.networks])

        mean = results.mean(axis=0)
        std = results.std(axis=0)

        if not batched:
            mean = mean[0]
            std = std[0]

        return mean, std


    def calibrate(self,dataset):
        pred,uncertainty = self.process(dataset[:][0].numpy(),perform_column_extraction=False)
        true = dataset[:][-1].numpy()
        abserr = np.abs(pred-true)

        calibration = np.mean(abserr,axis=0)/np.mean(uncertainty,axis=0)

        calibration /= 3
        self.err_info /= calibration

        inactive_columns = (np.std(abserr,axis=0)==0) & (np.std(uncertainty,axis=0)==0)

        warnings.warn("Inactive columns detected: {} , they will not be included in isokay.".format(np.where(inactive_columns)))
        self.err_info[inactive_columns]=np.inf


    def process_iserrok_fuzzy(self,errbars):
        return errbars/self.err_info

    def process_iserrok(self,errbars):
        return errbars < self.err_info

    def iserrok(self,errbars):
        errbars = self.pack_outputs(errbars)
        iserrok = self.process_iserrok(errbars)
        iserrok = self.unpack_outputs(iserrok)
        return iserrok

    def iserrok_fuzzy(self,errbars):
        errbars = self.pack_outputs(errbars)
        iserrok = self.process_iserrok_fuzzy(errbars)
        iserrok = self.unpack_outputs(iserrok)
        return iserrok

    def pack_outputs(self,request):
        return NotImplemented

    def pack_inputs(self,request):
        return NotImplemented

    def unpack_outputs(self,result):
        return NotImplemented


class LearnerModel(Model):
    def pack_inputs(self,request):
        packed_request = np.concatenate([[request.R],[request.Z]])
        return packed_request

    def unpack_outputs(self,packed_result):
        unpacked_result = Outputs(packed_result[0],packed_result[1],
                                  packed_result[2],packed_result[3],
                                  packed_result[4],packed_result[5],
                                  packed_result[6],packed_result[7],
                                  packed_result[8]
                                 )
        return unpacked_result

    def pack_outputs(self,outputs):
        output_vals = np.concatenate([[ouputs.BPHI], [outputs.BR], [outputs.BZ], [outputs.TE], [outputs.NE], [outputs.VE],
         [outputs.TI], [outputs.NI], [outputs.VI]])
        return output_vals,

# Parameters governing input and outputs to problem
SOLVER_INDEXES = dict(
        input_slice = slice(0,2),
        output_slice = slice(2,11),
        n_inputs = 2,
        n_outputs = 9,
)

#Parameters governing network structure
DEFAULT_NET_CONFIG = dict(
    n_layers=6,
    n_hidden=64,
    activation_type=torch.nn.ReLU,
    layer_type = torch.nn.Linear
    )

#Parameters for ensemble uncertainty
DEFAULT_ENSEMBLE_CONFIG = dict(
    n_members = 2, #5,
    test_fraction = 0.1, #0.5,
    score_thresh = 0.2, #0.7,
    max_model_tries = 200,
)


#Parameters for the optimization process
DEFAULT_TRAINING_CONFIG = dict(
    n_epochs=200, #00,
    optimizer_type=torch.optim.Adam,
    validation_fraction=0.2,
    lr=1e-3,
    patience=20,
    batch_size=50,
    eval_batch_size=100, #00,
    scheduler_type = torch.optim.lr_scheduler.ReduceLROnPlateau,
    cost_type = torch.nn.MSELoss
)

#Bundle of all learning-related parameters
DEFAULT_LEARNING_CONFIG = dict(
    net_config = DEFAULT_NET_CONFIG,
    ensemble_config = DEFAULT_ENSEMBLE_CONFIG,
    training_config = DEFAULT_TRAINING_CONFIG,
)

def assemble_dataset(raw_dataset):

    features = torch.as_tensor(raw_dataset[:,SOLVER_INDEXES["input_slice"]])
#    print("Feature shape:",features.shape)
#    print(features.std(axis=0))
    targets = torch.as_tensor(raw_dataset[:,SOLVER_INDEXES["output_slice"]])
#    print("Targets shape:",targets.shape)
#    print(targets.std(axis=0))
    return torch.utils.data.TensorDataset(features,targets)

#prototype, only covers ensemble uncertainties
def retrain(db_path,learning_config=DEFAULT_LEARNING_CONFIG):

    raw_dataset = getAllGNDData(db_path)
    full_dataset = assemble_dataset(raw_dataset)


    ensemble_config = learning_config["ensemble_config"]
    n_total = len(full_dataset)
    n_test = int(ensemble_config["test_fraction"]*n_total)
    n_test = max(n_test,2)
    n_train = n_total-n_test
    print("Total / train / test points:",n_total,n_train,n_test)

    networks = []
    network_errors = []
    network_scores = []

    successful_models = 0
    i=0
    while successful_models < ensemble_config["n_members"]:
        print("Training model {}".format(i))
        i += 1
        if i > ensemble_config["max_model_tries"]:
            break
        print("Good models found:",successful_models)
        print("Training ensemble member",i)

        train_data, test_data = torch.utils.data.random_split(full_dataset, (n_train, n_test))
#        print(len(train_data), len(test_data ))


        # This is a place where we could trivially parallelize training.

        this_model = train_single_model(train_data, learning_config=learning_config)
        model_score,model_errors = get_error_info(this_model,test_data)
        print("Score:",model_score)
        if any(m < ensemble_config["score_thresh"] for m in model_score):
            print("Rejected.")
            continue
        print("Accepted.")

        successful_models+=1

        networks.append(this_model)
        network_scores.append(model_score)
        network_errors.append(model_errors)

    error_info = np.mean(np.asarray(network_errors),axis=0)
#    full_model = SOLVER_INDEXES( networks, error_info)
    full_model = LearnerModel( networks, error_info)
    full_model.calibrate(full_dataset)

    return full_model


def train_single_model(train_data, learning_config):

    net_config = learning_config["net_config"]
    training_config = learning_config["training_config"]

    #Type parameters
    activation_type = net_config["activation_type"]
    layer_type = net_config["layer_type"]

    #Splitting
    n_total = len(train_data)
    n_valid = int(training_config["validation_fraction"]*n_total)
    n_valid = max(n_valid,2)
    n_train = n_total-n_valid
    #print(type(train_data),type(train_data[:]))

    #Stupid fix for now, but this trick doesn't hurt anything and enables the #Normalizing line to work
    train_data.indices = np.asarray(train_data.indices)
    train_data, valid_data = torch.utils.data.random_split(train_data, (n_train, n_valid))
    #print(type(train_data),type(train_data[:]))

    #Normalizing
    train_features, train_labels = (train_data[:])

    inscaler = Scaler.from_tensor(train_features)
    cost_scaler = Scaler.from_tensor(train_labels)
    outscaler = Scaler.from_inversion((cost_scaler))

    #Size parameters
    indices = SOLVER_INDEXES

    n_inputs = indices["n_inputs"]
    n_outputs = indices["n_outputs"]
    n_hidden = net_config["n_hidden"]

    layers = [inscaler,layer_type(n_inputs,n_hidden),activation_type()]

    for i in range(net_config["n_layers"]-2):
        layers.append(layer_type(n_hidden,n_hidden))
        layers.append(activation_type())
    layers.append(layer_type(n_hidden,n_outputs))

    train_network = torch.nn.Sequential(*layers)

    cost_fn = training_config["cost_type"]()
    opt = training_config["optimizer_type"](train_network.parameters(),lr=training_config["lr"])
    patience = training_config["patience"]
    scheduler = training_config["scheduler_type"](opt,patience=patience,verbose=False,factor=0.5)


    best_cost = np.inf
    best_params = train_network.state_dict()

    train_dloader = torch.utils.data.DataLoader(train_data,batch_size=training_config["batch_size"],shuffle=True)
    valid_dloader = torch.utils.data.DataLoader(valid_data,batch_size=training_config["eval_batch_size"],shuffle=False)

    # Need to add scales for costs
    for i in range(training_config["n_epochs"]):
        train_epoch(train_dloader,train_network,cost_fn,opt,scaler=cost_scaler)
        eval_cost = evaluate_dataset_errors(valid_dloader,train_network,scaler=cost_scaler).abs().mean().item()
        #if i%100==0: print(eval_cost)
        scheduler.step(eval_cost)
        if eval_cost < best_cost:
            #print("best epoch:",i)
            best_cost = eval_cost
            best_params = copy.deepcopy(train_network.state_dict())
            boredom = 0
        else:
            boredom +=1

        if boredom > 2*patience+1:
            print("Training finalized at epoch",i)
            break
    else:
        print("Training finished due to max epoch",i)


    train_network.load_state_dict(best_params)
    real_scale_network = torch.nn.Sequential(*train_network[:], outscaler)

    for param in real_scale_network.parameters():
        param.requires_grad_(False)

    return real_scale_network


def train_epoch(train_data,network,cost_fn,opt,scaler):
    for batch_in,batch_out in train_data:
        opt.zero_grad()
        batch_pred = network(batch_in)
        cost = cost_fn(batch_pred,scaler(batch_out))
        cost.backward()
        opt.step()

def evaluate_dataset_errors(dloader,network,scaler,show=False):
    predicted = []
    true = []
    with torch.autograd.no_grad():
        for bin,bout in dloader:

            bpred = network(bin)
            if scaler is not None:
                bout = scaler(bout)

            true.append(bout)
            predicted.append(bpred)

    true = torch.cat(true,dim=0)
    predicted = torch.cat(predicted,dim=0)
    err = predicted-true

    return err



def build_network(net_config):
    pass
    #do we need this? maybe for serializing more efficiently?

def l1_score(true,predicted):
    sum_abs_resid = np.abs(true-predicted).sum()
    med = np.median(true)
    sum_abs_dev = np.abs(true-med).sum()
    return 1 - sum_abs_resid/sum_abs_dev


def get_error_info(network,test_dset):
    test_dloader = torch.utils.data.DataLoader(test_dset,batch_size=100,shuffle=False)

    error = evaluate_dataset_errors(test_dloader,network,scaler=None).numpy()
    true = test_dset[:][-1].numpy()
    predicted = true + error
    return get_score(predicted,true)

def get_score(predicted,true):
    score = []
    rmse_list = []
    for i,(p,t) in enumerate(zip(predicted.T,true.T)):

        rmse = np.sqrt(sklearn.metrics.mean_squared_error(t,p))

        if p.std() < 1e-300 and t.std() < 1e-300:
            rsq = 1.
            l1resid = 1.
        else:
            rsq = sklearn.metrics.r2_score(t,p)
            l1resid = l1_score(t,p)

        score.append(rsq)
        rmse_list.append(rmse)

    #HARDCODED: TOTAL SCORE IS PRODUCT OF SCORES FOR EACH TARGET
    score = np.asarray(score)
    #score = np.prod(score*(score>0))
    rmse_list = np.asarray(rmse_list)
    return score,rmse_list

class Scaler(torch.nn.Module):
    def __init__(self,means,stds,eps=1e-300):
        super().__init__()
        self.means = torch.nn.Parameter(means,requires_grad=False)
        self.stds = torch.nn.Parameter(stds,requires_grad=False)
        self.eps  = eps

    @classmethod
    def from_tensor(cls,tensor):
        means = tensor.mean(dim=0)
        stds = tensor.std(dim=0)
        return cls(means,stds)

    @classmethod
    def from_inversion(cls,other):
        new_stds = 1/(other.stds+other.eps)
        new_means = -other.means/(other.stds+other.eps)
        return cls(new_means,new_stds)

    def forward(self,tensor):
        return (tensor-self.means)/(self.stds + self.eps)

# %%
import torch
# import nn_learner

DB_PATH='SOLEDGE.db'

model =retrain(db_path=DB_PATH)

#Ensure model can be pickled and unpickled.
torch.save(model,"data.pt")
# Out:
# Total / train / test points: 501 251 250
# Training model 0
# Good models found: 0
# Training ensemble member 1
# Training finalized at epoch 114
# Score: [ 0.99639742  0.99236462  0.99515855  0.47920383 -0.00579103 -0.00437448
#   0.45559881 -0.01326561 -0.02473923]
# Rejected.
# Training model 1
# Good models found: 0
# Training ensemble member 2
# Training finalized at epoch 79
# Score: [ 0.99578693  0.99256194  0.98896434  0.48034325  0.00304175 -0.00194297
#   0.45358157  0.00203977 -0.009857  ]
# Rejected.
# Training model 2
# Good models found: 0
# Training ensemble member 3
# Training finalized at epoch 111
# Score: [ 0.99689125  0.99498241  0.99279771  0.38784688 -0.02789715 -0.02900135
#   0.33312863 -0.02267406 -0.03098113]
# Rejected.
# Training model 3
# Good models found: 0
# Training ensemble member 4
# Training finalized at epoch 134
# Score: [ 0.99790013  0.99765593  0.99308719  0.45746086 -0.03257473 -0.01708755
#   0.44895321 -0.0300269  -0.0229896 ]
# Rejected.
# Training model 4
# Good models found: 0
# Training ensemble member 5
# Training finalized at epoch 86
# Score: [0.99547381 0.98267783 0.99295773 0.46170793 0.01526625 0.0157876
#  0.43632345 0.01004519 0.02807457]
# Rejected.
# Training model 5
# Good models found: 0
# Training ensemble member 6
# Training finalized at epoch 77
# Score: [ 0.99172351  0.99156715  0.99345132  0.44958686 -0.06128467 -0.06376132
#   0.41986177 -0.06676621 -0.06055986]
# Rejected.
# Training model 6
# Good models found: 0
# Training ensemble member 7
# Training finalized at epoch 107
# Score: [ 0.99768416  0.99642467  0.99473885  0.44952651 -0.0315648  -0.03994183
#   0.43656088 -0.03796406 -0.03738659]
# Rejected.
# Training model 7
# Good models found: 0
# Training ensemble member 8
# Training finalized at epoch 111
# Score: [ 9.95801074e-01  9.96458751e-01  9.90935735e-01  4.84310701e-01
#  -3.18800594e-04  8.08266145e-03  4.69057040e-01  1.71062620e-03
#   4.02058299e-03]
# Rejected.
# Training model 8
# Good models found: 0
# Training ensemble member 9
# Training finalized at epoch 76
# Score: [ 9.93848466e-01  9.93440367e-01  9.92863115e-01  4.60654687e-01
#  -3.25424826e-03  4.60035586e-03  4.41345697e-01 -6.79648950e-03
#   1.55226716e-04]
# Rejected.
# Training model 9
# Good models found: 0
# Training ensemble member 10
# Training finalized at epoch 61
# Score: [0.99477564 0.99241807 0.99278435 0.44593878 0.02074637 0.01673589
#  0.42176647 0.01525353 0.0181288 ]
# Rejected.
# Training model 10
# Good models found: 0
# Training ensemble member 11
# Training finalized at epoch 63
# Score: [ 0.99460857  0.99392333  0.98320593  0.47820362 -0.00312232 -0.01076376
#   0.45071504 -0.01567894 -0.00627203]
# Rejected.
# Training model 11
# Good models found: 0
# Training ensemble member 12
# Training finalized at epoch 90
# Score: [ 0.99722014  0.99597589  0.99200496  0.44343037 -0.03040512 -0.03369368
#   0.41878926 -0.05759962 -0.06253813]
# Rejected.
# Training model 12
# Good models found: 0
# Training ensemble member 13
# Training finalized at epoch 67
# Score: [ 0.99405129  0.98806409  0.99294665  0.46472411 -0.00214051  0.00460273
#   0.43305278  0.01400929  0.02272223]
# Rejected.
# Training model 13
# Good models found: 0
# Training ensemble member 14
# Training finalized at epoch 79
# Score: [ 0.99266439  0.99235899  0.98899342  0.45056986 -0.02963427 -0.02957474
#   0.41228608 -0.01207206 -0.01673924]
# Rejected.
# Training model 14
# Good models found: 0
# Training ensemble member 15
# Training finalized at epoch 85
# Score: [ 0.99833142  0.98926557  0.99262697  0.43940201 -0.03831189 -0.03723943
#   0.41738423 -0.0367517  -0.04359833]
# Rejected.
# Training model 15
# Good models found: 0
# Training ensemble member 16
# Training finalized at epoch 67
# Score: [ 0.99175992  0.99489245  0.98821486  0.48779884 -0.08024799 -0.09725167
#   0.45193154 -0.07789624 -0.08512568]
# Rejected.
# Training model 16
# Good models found: 0
# Training ensemble member 17
# Training finalized at epoch 108
# Score: [9.98768073e-01 9.95227928e-01 9.93373551e-01 4.80520699e-01
#  1.33258782e-02 1.40219104e-02 4.44939511e-01 7.20598712e-03
#  1.81085540e-04]
# Rejected.
# Training model 17
# Good models found: 0
# Training ensemble member 18
# Training finalized at epoch 77
# Score: [0.99235528 0.99733255 0.98857307 0.46367641 0.01798013 0.02078763
#  0.44197418 0.01915094 0.02304628]
# Rejected.
# Training model 18
# Good models found: 0
# Training ensemble member 19
# Training finalized at epoch 88
# Score: [0.99872884 0.99590947 0.99316378 0.41604962 0.00965919 0.01534461
#  0.41619403 0.00553    0.00955582]
# Rejected.
# Training model 19
# Good models found: 0
# Training ensemble member 20
# Training finalized at epoch 63
# Score: [0.99496956 0.99290336 0.99246539 0.48140136 0.01716057 0.00935442
#  0.46334165 0.01869006 0.01988522]
# Rejected.
# Training model 20
# Good models found: 0
# Training ensemble member 21
# Training finalized at epoch 70
# Score: [0.99568634 0.99519791 0.99033067 0.47038172 0.0365805  0.03097176
#  0.4541166  0.0360034  0.03092117]
# Rejected.
# Training model 21
# Good models found: 0
# Training ensemble member 22
# Training finalized at epoch 61
# Score: [0.99152263 0.99033001 0.98954556 0.4725384  0.00991658 0.02827947
#  0.44307176 0.01408771 0.02283259]
# Rejected.
# Training model 22
# Good models found: 0
# Training ensemble member 23
# Training finalized at epoch 74
# Score: [0.99195443 0.98780692 0.98842263 0.46607147 0.01339023 0.01426225
#  0.44122651 0.01010072 0.02267433]
# Rejected.
# Training model 23
# Good models found: 0
# Training ensemble member 24
# Training finalized at epoch 68
# Score: [ 0.99327553  0.99575188  0.99185938  0.48443121 -0.02682743 -0.00455628
#   0.44904694 -0.01349073 -0.01222983]
# Rejected.
# Training model 24
# Good models found: 0
# Training ensemble member 25
# Training finalized at epoch 163
# Score: [ 0.99567558  0.99574592  0.99330023  0.43795577 -0.03528981 -0.02607718
#   0.42307687 -0.03819705 -0.03684079]
# Rejected.
# Training model 25
# Good models found: 0
# Training ensemble member 26
# Training finalized at epoch 142
# Score: [ 0.98725118  0.98870259  0.98892066  0.42440299 -0.08195272 -0.06262479
#   0.41737727 -0.09012395 -0.07756073]
# Rejected.
# Training model 26
# Good models found: 0
# Training ensemble member 27
# Training finalized at epoch 59
# Score: [ 0.99278655  0.99417418  0.98723776  0.46876494  0.00601573 -0.00134447
#   0.44316648  0.00414423  0.00996138]
# Rejected.
# Training model 27
# Good models found: 0
# Training ensemble member 28
# Training finalized at epoch 78
# Score: [ 0.99080992  0.99513295  0.99149576  0.45199765  0.01543672  0.00401853
#   0.43433987 -0.01013733  0.01693567]
# Rejected.
# Training model 28
# Good models found: 0
# Training ensemble member 29
# Training finalized at epoch 84
# Score: [ 0.99495656  0.99384532  0.99274084  0.45052451 -0.01120133 -0.00783012
#   0.42678182 -0.02235926 -0.00811413]
# Rejected.
# Training model 29
# Good models found: 0
# Training ensemble member 30
# Training finalized at epoch 78
# Score: [0.99588987 0.98949231 0.99001166 0.45571817 0.01847725 0.02418111
#  0.43407317 0.00808775 0.01014977]
# Rejected.
# Training model 30
# Good models found: 0
# Training ensemble member 31
# Training finalized at epoch 90
# Score: [ 0.99583297  0.99677469  0.99021839  0.42120112 -0.03239183 -0.00532297
#   0.38243659 -0.02705753 -0.0118951 ]
# Rejected.
# Training model 31
# Good models found: 0
# Training ensemble member 32
# Training finalized at epoch 71
# Score: [ 0.996239    0.99521781  0.99302254  0.43864863 -0.02606525 -0.01804103
#   0.42867972 -0.02073303 -0.01316636]
# Rejected.
# Training model 32
# Good models found: 0
# Training ensemble member 33
# Training finalized at epoch 69
# Score: [ 9.95166121e-01  9.97511496e-01  9.93424110e-01  4.74971492e-01
#  -2.00811244e-04  9.69352580e-03  4.54249877e-01  1.34033687e-02
#   8.79133834e-03]
# Rejected.
# Training model 33
# Good models found: 0
# Training ensemble member 34
# Training finalized at epoch 77
# Score: [0.99284725 0.9947877  0.99090393 0.45444251 0.01488126 0.03003838
#  0.45032429 0.01905397 0.01915667]
# Rejected.
# Training model 34
# Good models found: 0
# Training ensemble member 35
# Training finalized at epoch 67
# Score: [ 0.99693814  0.98393952  0.99298034  0.45951684 -0.04559151 -0.03090026
#   0.42329397 -0.06216838 -0.05421761]
# Rejected.
# Training model 35
# Good models found: 0
# Training ensemble member 36
# Training finalized at epoch 93
# Score: [ 0.99716442  0.98858223  0.99244739  0.44761542 -0.03278069 -0.0368204
#   0.415832   -0.03551881 -0.04069346]
# Rejected.
# Training model 36
# Good models found: 0
# Training ensemble member 37
# Training finalized at epoch 145
# Score: [0.99864571 0.99741428 0.99406198 0.47804183 0.01713957 0.0242132
#  0.46693864 0.0145667  0.02114575]
# Rejected.
# Training model 37
# Good models found: 0
# Training ensemble member 38
# Training finalized at epoch 95
# Score: [ 9.95858661e-01  9.95184435e-01  9.92070017e-01  3.94904444e-01
#   8.52871120e-04  5.17208314e-04  3.91062779e-01  3.25782174e-03
#  -2.92995087e-03]
# Rejected.
# Training model 38
# Good models found: 0
# Training ensemble member 39
# Training finalized at epoch 103
# Score: [0.99833489 0.9970609  0.99314086 0.49004389 0.002958   0.01380067
#  0.47706218 0.00707054 0.00657032]
# Rejected.
# Training model 39
# Good models found: 0
# Training ensemble member 40
# Training finalized at epoch 69
# Score: [ 0.99581567  0.99483218  0.99155833  0.48335075 -0.00507054  0.00121296
#   0.44777075  0.00252742  0.01003012]
# Rejected.
# Training model 40
# Good models found: 0
# Training ensemble member 41
# Training finalized at epoch 90
# Score: [0.99355807 0.99520121 0.9918121  0.43405907 0.00797568 0.00887101
#  0.42034249 0.00698388 0.01576987]
# Rejected.
# Training model 41
# Good models found: 0
# Training ensemble member 42
# Training finalized at epoch 139
# Score: [ 0.99802045  0.99730982  0.99486318  0.44202166 -0.01816001 -0.01336138
#   0.4128141  -0.02844983 -0.0213787 ]
# Rejected.
# Training model 42
# Good models found: 0
# Training ensemble member 43
# Training finalized at epoch 74
# Score: [ 0.99480913  0.99264262  0.98780211  0.46789067 -0.04097145 -0.05654567
#   0.43678621 -0.06046384 -0.04685258]
# Rejected.
# Training model 43
# Good models found: 0
# Training ensemble member 44
# Training finalized at epoch 94
# Score: [ 9.98704345e-01  9.93130224e-01  9.92841839e-01  4.41176211e-01
#  -2.11440267e-03  1.01765414e-03  4.13253378e-01  9.13913024e-03
#   7.98265858e-04]
# Rejected.
# Training model 44
# Good models found: 0
# Training ensemble member 45
# Training finalized at epoch 71
# Score: [ 0.99166166  0.99707197  0.99279789  0.47914589 -0.04211541 -0.03940252
#   0.45767301 -0.05083257 -0.04104783]
# Rejected.
# Training model 45
# Good models found: 0
# Training ensemble member 46
# Training finalized at epoch 72
# Score: [9.95505227e-01 9.91553872e-01 9.92533037e-01 4.57963189e-01
#  2.14893007e-03 1.58859339e-02 4.33871837e-01 4.81806565e-04
#  2.37035675e-03]
# Rejected.
# Training model 46
# Good models found: 0
# Training ensemble member 47
# Training finalized at epoch 103
# Score: [0.99839576 0.98990749 0.99348792 0.45014341 0.01746119 0.01604078
#  0.4387273  0.00869825 0.01615212]
# Rejected.
# Training model 47
# Good models found: 0
# Training ensemble member 48
# Training finalized at epoch 61
# Score: [ 0.99515157  0.98726616  0.98320589  0.43040487 -0.03109282 -0.05789592
#   0.39792494 -0.03797367 -0.02966895]
# Rejected.
# Training model 48
# Good models found: 0
# Training ensemble member 49
# Training finalized at epoch 96
# Score: [ 9.98576360e-01  9.92535629e-01  9.89835117e-01  4.27905321e-01
#   2.51145144e-03  3.87076762e-03  3.89954724e-01  6.09053532e-04
#  -5.91979655e-05]
# Rejected.
# Training model 49
# Good models found: 0
# Training ensemble member 50
# Training finalized at epoch 56
# Score: [0.98952963 0.98146225 0.99267498 0.44944047 0.00659298 0.01011238
#  0.44286913 0.01031336 0.00899742]
# Rejected.
# Training model 50
# Good models found: 0
# Training ensemble member 51
# Training finalized at epoch 73
# Score: [0.99713052 0.99139061 0.99195691 0.45535476 0.01718334 0.02021852
#  0.4425852  0.01473571 0.02663997]
# Rejected.
# Training model 51
# Good models found: 0
# Training ensemble member 52
# Training finalized at epoch 109
# Score: [ 0.99688513  0.99829114  0.99377959  0.44443104 -0.00549647  0.00725781
#   0.42382661  0.00613414  0.00546908]
# Rejected.
# Training model 52
# Good models found: 0
# Training ensemble member 53
# Training finalized at epoch 120
# Score: [ 0.98864968  0.99732838  0.98962174  0.46693083 -0.00441174  0.00203654
#   0.44744683 -0.00360819 -0.00194523]
# Rejected.
# Training model 53
# Good models found: 0
# Training ensemble member 54
# Training finalized at epoch 120
# Score: [ 0.99728258  0.99597984  0.99478607  0.4592346  -0.02884088 -0.02893089
#   0.43519362 -0.03524299 -0.02955166]
# Rejected.
# Training model 54
# Good models found: 0
# Training ensemble member 55
# Training finalized at epoch 66
# Score: [ 0.99505668  0.99616223  0.9914654   0.44705842 -0.0014818   0.00466894
#   0.42624683 -0.0025755   0.00291832]
# Rejected.
# Training model 55
# Good models found: 0
# Training ensemble member 56
# Training finalized at epoch 72
# Score: [ 0.99496639  0.98196708  0.9880046   0.42759348 -0.06004678 -0.06370755
#   0.40097185 -0.05604217 -0.05042828]
# Rejected.
# Training model 56
# Good models found: 0
# Training ensemble member 57
# Training finalized at epoch 76
# Score: [ 0.9956687   0.99448405  0.99284506  0.42931467 -0.03031605 -0.04906503
#   0.39564615 -0.03892281 -0.04152586]
# Rejected.
# Training model 57
# Good models found: 0
# Training ensemble member 58
# Training finalized at epoch 101
# Score: [ 9.96058258e-01  9.96172041e-01  9.92824152e-01  4.45431479e-01
#   5.99649631e-03  6.36684995e-03  4.13505975e-01 -1.89849206e-03
#  -2.71685590e-04]
# Rejected.
# Training model 58
# Good models found: 0
# Training ensemble member 59
# Training finalized at epoch 103
# Score: [ 0.99882281  0.9962092   0.9941106   0.4691017  -0.01082375 -0.01150594
#   0.44877458 -0.02265685 -0.01154557]
# Rejected.
# Training model 59
# Good models found: 0
# Training ensemble member 60
# Training finalized at epoch 144
# Score: [ 0.99763601  0.99393689  0.99367169  0.46630336 -0.02055453 -0.00971608
#   0.45624668 -0.02128932 -0.00816147]
# Rejected.
# Training model 60
# Good models found: 0
# Training ensemble member 61
# Training finalized at epoch 164
# Score: [0.99885638 0.99750812 0.99469534 0.44276718 0.01508515 0.0103167
#  0.40287892 0.01179636 0.01755861]
# Rejected.
# Training model 61
# Good models found: 0
# Training ensemble member 62
# Training finalized at epoch 67
# Score: [ 0.98780413  0.99327304  0.98870366  0.48205082 -0.01083748  0.00280222
#   0.4622302  -0.0075979  -0.00186922]
# Rejected.
# Training model 62
# Good models found: 0
# Training ensemble member 63
# Training finalized at epoch 82
# Score: [0.99777358 0.99473442 0.99276069 0.4706438  0.01389851 0.00550144
#  0.45015657 0.01234695 0.01369077]
# Rejected.
# Training model 63
# Good models found: 0
# Training ensemble member 64
# Training finalized at epoch 58
# Score: [ 0.99734954  0.96070654  0.9870862   0.44309429 -0.00910723  0.00247329
#   0.39965788 -0.00143579  0.01618795]
# Rejected.
# Training model 64
# Good models found: 0
# Training ensemble member 65
# Training finalized at epoch 69
# Score: [ 0.98892873  0.99510411  0.98678625  0.45318843 -0.03745926 -0.0433131
#   0.42965423 -0.04965261 -0.04032655]
# Rejected.
# Training model 65
# Good models found: 0
# Training ensemble member 66
# Training finalized at epoch 95
# Score: [ 0.99680417  0.99447072  0.99356088  0.46742996 -0.02563292 -0.01224075
#   0.43101476 -0.024966   -0.01173693]
# Rejected.
# Training model 66
# Good models found: 0
# Training ensemble member 67
# Training finalized at epoch 77
# Score: [ 0.98721594  0.98778138  0.98742772  0.4554377  -0.00845295 -0.007065
#   0.43639694 -0.02025638 -0.01043879]
# Rejected.
# Training model 67
# Good models found: 0
# Training ensemble member 68
# Training finalized at epoch 126
# Score: [0.99828143 0.99777843 0.99395819 0.45035432 0.00843347 0.01734509
#  0.43207254 0.01402718 0.00956482]
# Rejected.
# Training model 68
# Good models found: 0
# Training ensemble member 69
# Training finalized at epoch 115
# Score: [ 0.994177    0.9944756   0.9907009   0.46310017 -0.03873875 -0.01771055
#   0.43669946 -0.0354271  -0.01486695]
# Rejected.
# Training model 69
# Good models found: 0
# Training ensemble member 70
# Training finalized at epoch 66
# Score: [ 0.9959809   0.98998419  0.99351236  0.45350895 -0.05697224 -0.04567169
#   0.39150081 -0.05605667 -0.03586478]
# Rejected.
# Training model 70
# Good models found: 0
# Training ensemble member 71
# Training finalized at epoch 120
# Score: [0.99326416 0.99635832 0.99119867 0.46633761 0.01344287 0.01504053
#  0.44972626 0.01458904 0.01481186]
# Rejected.
# Training model 71
# Good models found: 0
# Training ensemble member 72
# Training finalized at epoch 74
# Score: [ 0.99522719  0.98894473  0.99307602  0.45861562 -0.00950437 -0.02785736
#   0.42928153  0.00536876 -0.00571367]
# Rejected.
# Training model 72
# Good models found: 0
# Training ensemble member 73
# Training finalized at epoch 116
# Score: [ 0.99622366  0.99348333  0.99047748  0.44574079 -0.03565713 -0.03192887
#   0.41703164 -0.03909148 -0.03170065]
# Rejected.
# Training model 73
# Good models found: 0
# Training ensemble member 74
# Training finalized at epoch 84
# Score: [ 0.99598968  0.98933775  0.99013077  0.43825382 -0.02392474 -0.01578427
#   0.42476247 -0.00330959 -0.0231664 ]
# Rejected.
# Training model 74
# Good models found: 0
# Training ensemble member 75
# Training finalized at epoch 90
# Score: [0.9958795  0.99664465 0.99185616 0.46160049 0.00949246 0.03978901
#  0.44023631 0.0212973  0.03137415]
# Rejected.
# Training model 75
# Good models found: 0
# Training ensemble member 76
# Training finalized at epoch 126
# Score: [ 0.99780235  0.99723234  0.99495642  0.48009467 -0.01640758 -0.0053171
#   0.45770629 -0.01485919 -0.00543869]
# Rejected.
# Training model 76
# Good models found: 0
# Training ensemble member 77
# Training finalized at epoch 101
# Score: [ 0.99825275  0.99348041  0.99223981  0.37269206 -0.01992481 -0.01577264
#   0.33703631 -0.02415476 -0.0122355 ]
# Rejected.
# Training model 77
# Good models found: 0
# Training ensemble member 78
# Training finalized at epoch 120
# Score: [ 0.99803296  0.9978161   0.99375815  0.43011621 -0.01429827 -0.01524796
#   0.40350868 -0.01945488 -0.01561509]
# Rejected.
# Training model 78
# Good models found: 0
# Training ensemble member 79
# Training finalized at epoch 238
# Score: [0.99930537 0.99827891 0.99434017 0.46462306 0.01808441 0.02461191
#  0.45566494 0.01937381 0.02089785]
# Rejected.
# Training model 79
# Good models found: 0
# Training ensemble member 80
# Training finalized at epoch 76
# Score: [0.99591977 0.99192885 0.99016639 0.46052493 0.0149608  0.01364337
#  0.44174164 0.00861632 0.01261287]
# Rejected.
# Training model 80
# Good models found: 0
# Training ensemble member 81
# Training finalized at epoch 149
# Score: [0.99771227 0.99858372 0.99341929 0.48535112 0.0292622  0.03730247
#  0.468344   0.02925904 0.02795646]
# Rejected.
# Training model 81
# Good models found: 0
# Training ensemble member 82
# Training finalized at epoch 108
# Score: [ 0.99757997  0.99572388  0.99155491  0.42515347  0.00159106  0.00154276
#   0.38239157 -0.00435586  0.00644369]
# Rejected.
# Training model 82
# Good models found: 0
# Training ensemble member 83
# Training finalized at epoch 60
# Score: [ 0.99064746  0.99465172  0.98869818  0.47498395 -0.00376204  0.02092098
#   0.44837287  0.01172109  0.01388187]
# Rejected.
# Training model 83
# Good models found: 0
# Training ensemble member 84
# Training finalized at epoch 148
# Score: [ 0.99458203  0.99667634  0.99328029  0.45114004 -0.02782146 -0.03435975
#   0.43135555 -0.0333524  -0.03576146]
# Rejected.
# Training model 84
# Good models found: 0
# Training ensemble member 85
# Training finalized at epoch 119
# Score: [0.99909289 0.99541129 0.99366107 0.48105893 0.00380103 0.00752053
#  0.46135266 0.00545548 0.01247529]
# Rejected.
# Training model 85
# Good models found: 0
# Training ensemble member 86
# Training finalized at epoch 143
# Score: [ 9.95126694e-01  9.96496745e-01  9.93993567e-01  4.51366611e-01
#   7.97316440e-03 -1.01060798e-02  4.33111195e-01  6.34278153e-04
#  -7.28276496e-03]
# Rejected.
# Training model 86
# Good models found: 0
# Training ensemble member 87
# Training finalized at epoch 147
# Score: [ 9.98562179e-01  9.97413452e-01  9.87783427e-01  4.62486347e-01
#  -2.20342974e-02 -7.22758874e-04  4.46976136e-01 -1.17053192e-02
#  -1.42471229e-02]
# Rejected.
# Training model 87
# Good models found: 0
# Training ensemble member 88
# Training finalized at epoch 56
# Score: [0.98549574 0.99473917 0.98710633 0.4617449  0.02217639 0.03380988
#  0.43129911 0.02906612 0.03272695]
# Rejected.
# Training model 88
# Good models found: 0
# Training ensemble member 89
# Training finalized at epoch 97
# Score: [ 0.99186488  0.99524792  0.99203291  0.44119802 -0.02764528 -0.01495449
#   0.41297109 -0.03042843 -0.00440672]
# Rejected.
# Training model 89
# Good models found: 0
# Training ensemble member 90
# Training finalized at epoch 64
# Score: [0.99697182 0.99138303 0.99272097 0.45731752 0.00334764 0.00655819
#  0.45059535 0.00814534 0.00412614]
# Rejected.
# Training model 90
# Good models found: 0
# Training ensemble member 91
# Training finalized at epoch 68
# Score: [ 0.99390186  0.98297155  0.98794247  0.46858144 -0.01870923 -0.02178683
#   0.45832073 -0.01410423 -0.02676389]
# Rejected.
# Training model 91
# Good models found: 0
# Training ensemble member 92
# Training finalized at epoch 165
# Score: [0.99733252 0.99811938 0.99492219 0.47367625 0.02330442 0.03127304
#  0.4602797  0.03172128 0.02692729]
# Rejected.
# Training model 92
# Good models found: 0
# Training ensemble member 93
# Training finalized at epoch 81
# Score: [9.94828187e-01 9.93810341e-01 9.90871139e-01 4.87721772e-01
#  2.67576067e-04 1.26601209e-02 4.54425937e-01 2.38259556e-03
#  1.00867151e-02]
# Rejected.
# Training model 93
# Good models found: 0
# Training ensemble member 94
# Training finalized at epoch 119
# Score: [ 0.99763134  0.99389958  0.99343083  0.44658069 -0.0042757  -0.00843342
#   0.42634141 -0.00272367  0.00178257]
# Rejected.
# Training model 94
# Good models found: 0
# Training ensemble member 95
# Training finalized at epoch 110
# Score: [0.99800474 0.99402776 0.99215275 0.47243086 0.0058817  0.01641435
#  0.4522778  0.01009015 0.00913207]
# Rejected.
# Training model 95
# Good models found: 0
# Training ensemble member 96
# Training finalized at epoch 102
# Score: [ 0.99558788  0.99726933  0.99211348  0.4850024  -0.01550058 -0.01732271
#   0.45286813 -0.0211562  -0.01673572]
# Rejected.
# Training model 96
# Good models found: 0
# Training ensemble member 97
# Training finalized at epoch 67
# Score: [ 9.81232838e-01  9.85704265e-01  9.80111358e-01  4.93609699e-01
#  -1.77878520e-03  1.11336858e-02  4.63481718e-01  1.74133955e-04
#  -4.33533232e-03]
# Rejected.
# Training model 97
# Good models found: 0
# Training ensemble member 98
# Training finalized at epoch 81
# Score: [ 9.92994488e-01  9.90953439e-01  9.91272086e-01  4.69239181e-01
#   1.47882179e-03  1.33658747e-02  4.36515738e-01 -8.26643046e-04
#   1.42790840e-02]
# Rejected.
# Training model 98
# Good models found: 0
# Training ensemble member 99
# Training finalized at epoch 80
# Score: [0.99683323 0.98444953 0.99042507 0.46044289 0.02170161 0.02164389
#  0.42795159 0.02361012 0.02541696]
# Rejected.
# Training model 99
# Good models found: 0
# Training ensemble member 100
# Training finalized at epoch 94
# Score: [ 0.99804112  0.99518773  0.99389142  0.45154379  0.00327383 -0.00379001
#   0.42801331  0.00365829 -0.00392969]
# Rejected.
# Training model 100
# Good models found: 0
# Training ensemble member 101
# Training finalized at epoch 123
# Score: [ 0.99818456  0.99752807  0.99112572  0.39518504 -0.04000656 -0.04725481
#   0.37792153 -0.04425386 -0.04879267]
# Rejected.
# Training model 101
# Good models found: 0
# Training ensemble member 102
# Training finalized at epoch 182
# Score: [0.99836892 0.99838621 0.99333229 0.48188186 0.00744268 0.01154507
#  0.46583175 0.00506486 0.01928669]
# Rejected.
# Training model 102
# Good models found: 0
# Training ensemble member 103
# Training finalized at epoch 95
# Score: [0.99450516 0.99693932 0.99164211 0.48852621 0.00920694 0.02030513
#  0.46580307 0.01221144 0.01573442]
# Rejected.
# Training model 103
# Good models found: 0
# Training ensemble member 104
# Training finalized at epoch 99
# Score: [ 0.99594111  0.99606035  0.99381233  0.4383222  -0.02399994 -0.01042378
#   0.40359143 -0.02529566 -0.0092454 ]
# Rejected.
# Training model 104
# Good models found: 0
# Training ensemble member 105
# Training finalized at epoch 99
# Score: [ 0.99897423  0.99731054  0.99313257  0.45540761 -0.06064995 -0.04621386
#   0.42802429 -0.05492284 -0.05482364]
# Rejected.
# Training model 105
# Good models found: 0
# Training ensemble member 106
# Training finalized at epoch 55
# Score: [0.9855659  0.99347777 0.9858316  0.46571418 0.02820014 0.04076279
#  0.46233416 0.03063485 0.03080805]
# Rejected.
# Training model 106
# Good models found: 0
# Training ensemble member 107
# Training finalized at epoch 62
# Score: [ 0.99434596  0.98151136  0.9907305   0.47636613 -0.04199064 -0.04162578
#   0.4477868  -0.02119362 -0.01269146]
# Rejected.
# Training model 107
# Good models found: 0
# Training ensemble member 108
# Training finalized at epoch 91
# Score: [0.99686092 0.99170386 0.99354794 0.46619002 0.01087034 0.01936793
#  0.45049331 0.01978433 0.01485413]
# Rejected.
# Training model 108
# Good models found: 0
# Training ensemble member 109
# Training finalized at epoch 96
# Score: [0.9974714  0.99491585 0.99220728 0.46625088 0.02127165 0.02549883
#  0.43712773 0.02051085 0.02724519]
# Rejected.
# Training model 109
# Good models found: 0
# Training ensemble member 110
# Training finalized at epoch 119
# Score: [ 0.99691339  0.99673114  0.98989838  0.4722947  -0.04625773 -0.04751769
#   0.45517554 -0.05869774 -0.05642171]
# Rejected.
# Training model 110
# Good models found: 0
# Training ensemble member 111
# Training finalized at epoch 84
# Score: [ 9.97195645e-01  9.95082629e-01  9.92494625e-01  4.53284455e-01
#  -1.13027929e-04  2.98267655e-03  4.38436340e-01  3.35702422e-03
#  -1.10755621e-03]
# Rejected.
# Training model 111
# Good models found: 0
# Training ensemble member 112
# Training finalized at epoch 115
# Score: [9.98460260e-01 9.97218485e-01 9.93373830e-01 4.68624094e-01
#  6.03468457e-04 5.43753611e-03 4.43321398e-01 2.31816000e-03
#  8.58728913e-03]
# Rejected.
# Training model 112
# Good models found: 0
# Training ensemble member 113
# Training finalized at epoch 71
# Score: [ 0.99615869  0.99360259  0.99380777  0.45690429 -0.02673365 -0.0247683
#   0.42937011 -0.02375916 -0.03507858]
# Rejected.
# Training model 113
# Good models found: 0
# Training ensemble member 114
# Training finalized at epoch 59
# Score: [ 0.98132117  0.98150189  0.99003221  0.47923818 -0.05194244 -0.04115845
#   0.46885796 -0.05680484 -0.04121985]
# Rejected.
# Training model 114
# Good models found: 0
# Training ensemble member 115
# Training finalized at epoch 107
# Score: [ 0.99720284  0.99232     0.99425607  0.45335792  0.00412277  0.00134284
#   0.43198709 -0.00140729 -0.00131409]
# Rejected.
# Training model 115
# Good models found: 0
# Training ensemble member 116
# Training finalized at epoch 61
# Score: [ 0.99212748  0.99027004  0.98751724  0.45502252 -0.042477   -0.02541434
#   0.42410217 -0.01962548 -0.02261276]
# Rejected.
# Training model 116
# Good models found: 0
# Training ensemble member 117
# Training finalized at epoch 125
# Score: [0.99709613 0.99427278 0.9927568  0.4182442  0.01023184 0.01048416
#  0.39937323 0.00886909 0.01013908]
# Rejected.
# Training model 117
# Good models found: 0
# Training ensemble member 118
# Training finalized at epoch 64
# Score: [ 0.99847718  0.99407711  0.99277359  0.46666211 -0.04554195 -0.05356018
#   0.44795908 -0.04899239 -0.04384626]
# Rejected.
# Training model 118
# Good models found: 0
# Training ensemble member 119
# Training finalized at epoch 162
# Score: [0.99904541 0.99735861 0.9947345  0.47382162 0.01341276 0.01639561
#  0.4537204  0.00888326 0.02018726]
# Rejected.
# Training model 119
# Good models found: 0
# Training ensemble member 120
# Training finalized at epoch 61
# Score: [ 0.99255761  0.99445389  0.99140633  0.44984543 -0.01687286 -0.00983616
#   0.42397775 -0.00619925 -0.01904775]
# Rejected.
# Training model 120
# Good models found: 0
# Training ensemble member 121
# Training finalized at epoch 129
# Score: [ 9.97670014e-01  9.94194593e-01  9.93289010e-01  4.76477572e-01
#   1.26979801e-03  1.30827288e-02  4.49216450e-01 -8.72975492e-04
#   7.99859773e-03]
# Rejected.
# Training model 121
# Good models found: 0
# Training ensemble member 122
# Training finalized at epoch 74
# Score: [0.99177844 0.99241169 0.99225197 0.46967896 0.03037059 0.0383568
#  0.45515927 0.02614933 0.03527024]
# Rejected.
# Training model 122
# Good models found: 0
# Training ensemble member 123
# Training finalized at epoch 84
# Score: [0.993744   0.99060601 0.99254777 0.47554286 0.01939371 0.02463508
#  0.45853527 0.01273493 0.02356438]
# Rejected.
# Training model 123
# Good models found: 0
# Training ensemble member 124
# Training finalized at epoch 87
# Score: [ 0.99554098  0.98980164  0.99227762  0.46715262 -0.01383528 -0.01831155
#   0.45059877 -0.02288378 -0.01850452]
# Rejected.
# Training model 124
# Good models found: 0
# Training ensemble member 125
# Training finalized at epoch 72
# Score: [ 0.99034424  0.99609019  0.99026499  0.4607615  -0.02347626 -0.03183991
#   0.45198193 -0.01825719 -0.03333756]
# Rejected.
# Training model 125
# Good models found: 0
# Training ensemble member 126
# Training finalized at epoch 86
# Score: [0.9984781  0.99608338 0.99082288 0.46321761 0.02719216 0.02941938
#  0.44649191 0.02667596 0.0301027 ]
# Rejected.
# Training model 126
# Good models found: 0
# Training ensemble member 127
# Training finalized at epoch 123
# Score: [0.99835307 0.98789203 0.99378369 0.40535058 0.04151975 0.04533679
#  0.37640102 0.0463792  0.04479393]
# Rejected.
# Training model 127
# Good models found: 0
# Training ensemble member 128
# Training finalized at epoch 111
# Score: [ 0.9970362   0.99696484  0.99050112  0.47294315 -0.02492393 -0.01409968
#   0.45216929 -0.00848514 -0.03002382]
# Rejected.
# Training model 128
# Good models found: 0
# Training ensemble member 129
# Training finalized at epoch 169
# Score: [ 0.99876814  0.9921279   0.99277054  0.40987726 -0.03109183 -0.02442159
#   0.38040727 -0.03629025 -0.03582496]
# Rejected.
# Training model 129
# Good models found: 0
# Training ensemble member 130
# Training finalized at epoch 69
# Score: [ 0.99336076  0.99614445  0.99256213  0.46947322 -0.01839059 -0.0292862
#   0.44658861 -0.01540921 -0.02124033]
# Rejected.
# Training model 130
# Good models found: 0
# Training ensemble member 131
# Training finalized at epoch 124
# Score: [0.9975152  0.99662634 0.99141488 0.47874322 0.0140823  0.00826597
#  0.4556319  0.00888541 0.02808246]
# Rejected.
# Training model 131
# Good models found: 0
# Training ensemble member 132
# Training finalized at epoch 88
# Score: [0.99738029 0.99217701 0.99355378 0.48071954 0.02787439 0.03002593
#  0.46022004 0.03051791 0.02655072]
# Rejected.
# Training model 132
# Good models found: 0
# Training ensemble member 133
# Training finalized at epoch 162
# Score: [0.99929662 0.99802517 0.9931757  0.45652406 0.0168408  0.01352354
#  0.44393922 0.01526697 0.01905585]
# Rejected.
# Training model 133
# Good models found: 0
# Training ensemble member 134
# Training finalized at epoch 111
# Score: [ 0.98949428  0.9960076   0.98968471  0.43588491 -0.07508607 -0.05052356
#   0.41798403 -0.05650783 -0.05755102]
# Rejected.
# Training model 134
# Good models found: 0
# Training ensemble member 135
# Training finalized at epoch 75
# Score: [ 0.98863543  0.98775209  0.98838967  0.47672138 -0.0191559  -0.04539523
#   0.44923454 -0.02733361 -0.01305108]
# Rejected.
# Training model 135
# Good models found: 0
# Training ensemble member 136
# Training finalized at epoch 98
# Score: [ 0.99642852  0.99311318  0.99213222  0.43189703  0.01052127  0.01365745
#   0.42514685 -0.00198042  0.01060889]
# Rejected.
# Training model 136
# Good models found: 0
# Training ensemble member 137
# Training finalized at epoch 145
# Score: [ 0.99815409  0.99669362  0.99384077  0.47843702 -0.0179202  -0.01009456
#   0.4597903  -0.01771167 -0.0073967 ]
# Rejected.
# Training model 137
# Good models found: 0
# Training ensemble member 138
# Training finalized at epoch 54
# Score: [ 9.59030355e-01  9.80164375e-01  9.74650023e-01  4.37136183e-01
#  -6.79030921e-04  7.79290056e-03  4.31307887e-01 -1.40192327e-02
#  -1.78375151e-03]
# Rejected.
# Training model 138
# Good models found: 0
# Training ensemble member 139
# Training finalized at epoch 63
# Score: [ 0.99325002  0.99132958  0.98852864  0.48326651 -0.03793318 -0.02004594
#   0.45182314 -0.08618012 -0.02152727]
# Rejected.
# Training model 139
# Good models found: 0
# Training ensemble member 140
# Training finalized at epoch 74
# Score: [ 0.98936968  0.99414136  0.98865447  0.43868482 -0.00652672 -0.00983545
#   0.41929863 -0.01025608 -0.02094996]
# Rejected.
# Training model 140
# Good models found: 0
# Training ensemble member 141
# Training finalized at epoch 74
# Score: [ 9.91479343e-01  9.91493653e-01  9.90355648e-01  4.38726111e-01
#  -2.88066358e-03 -4.64501558e-04  3.93249834e-01  6.99159053e-04
#   2.04163099e-03]
# Rejected.
# Training model 141
# Good models found: 0
# Training ensemble member 142
# Training finalized at epoch 118
# Score: [ 0.99620188  0.9977539   0.99212318  0.4737604  -0.00260063  0.01023604
#   0.45253872  0.00177011  0.00733062]
# Rejected.
# Training model 142
# Good models found: 0
# Training ensemble member 143
# Training finalized at epoch 118
# Score: [ 0.99666157  0.99670001  0.99342591  0.46196389 -0.03173599 -0.03499522
#   0.44041273 -0.0365548  -0.03610855]
# Rejected.
# Training model 143
# Good models found: 0
# Training ensemble member 144
# Training finalized at epoch 58
# Score: [ 0.99031602  0.99563387  0.98840612  0.47918784 -0.01040794 -0.00347484
#   0.4575933  -0.00339036 -0.00786241]
# Rejected.
# Training model 144
# Good models found: 0
# Training ensemble member 145
# Training finalized at epoch 96
# Score: [ 0.996213    0.98849669  0.99275257  0.48241429 -0.03634023 -0.01859731
#   0.46802947 -0.02663919 -0.03227603]
# Rejected.
# Training model 145
# Good models found: 0
# Training ensemble member 146
# Training finalized at epoch 92
# Score: [0.99360765 0.99231885 0.98874331 0.44677158 0.02597379 0.02397404
#  0.42113317 0.02872491 0.02602245]
# Rejected.
# Training model 146
# Good models found: 0
# Training ensemble member 147
# Training finalized at epoch 83
# Score: [0.99651782 0.99625097 0.9921984  0.46627682 0.00503297 0.01265141
#  0.44620752 0.00938299 0.01884802]
# Rejected.
# Training model 147
# Good models found: 0
# Training ensemble member 148
# Training finalized at epoch 82
# Score: [ 9.90052436e-01  9.95301637e-01  9.88603416e-01  4.62460326e-01
#  -3.77812697e-03  1.04680197e-02  4.48914571e-01 -5.54783200e-04
#   2.47034337e-03]
# Rejected.
# Training model 148
# Good models found: 0
# Training ensemble member 149
# Training finalized at epoch 75
# Score: [0.99609256 0.99622759 0.99483275 0.47733741 0.00706538 0.01813179
#  0.43610318 0.01223518 0.01813896]
# Rejected.
# Training model 149
# Good models found: 0
# Training ensemble member 150
# Training finalized at epoch 83
# Score: [0.99552297 0.98932785 0.99095982 0.44006547 0.02046443 0.01118316
#  0.41422624 0.00418923 0.01543142]
# Rejected.
# Training model 150
# Good models found: 0
# Training ensemble member 151
# Training finalized at epoch 72
# Score: [ 0.99472235  0.99339344  0.98757796  0.45409972  0.00213349 -0.00274159
#   0.43534948 -0.01111544 -0.01733132]
# Rejected.
# Training model 151
# Good models found: 0
# Training ensemble member 152
# Training finalized at epoch 114
# Score: [0.99794945 0.99828893 0.99395957 0.46837581 0.00760364 0.01626652
#  0.45663134 0.01280939 0.01288813]
# Rejected.
# Training model 152
# Good models found: 0
# Training ensemble member 153
# Training finalized at epoch 145
# Score: [0.99844452 0.99820256 0.99514004 0.44295796 0.00592457 0.00948564
#  0.42577831 0.01031001 0.01125797]
# Rejected.
# Training model 153
# Good models found: 0
# Training ensemble member 154
# Training finalized at epoch 122
# Score: [ 0.99435483  0.99741574  0.99105988  0.47621072  0.00336843  0.00216593
#   0.45360273 -0.00320074 -0.00246876]
# Rejected.
# Training model 154
# Good models found: 0
# Training ensemble member 155
# Training finalized at epoch 97
# Score: [ 0.99572985  0.99586128  0.99277963  0.45483705 -0.02646502 -0.02664779
#   0.43350616 -0.01755125 -0.03242952]
# Rejected.
# Training model 155
# Good models found: 0
# Training ensemble member 156
# Training finalized at epoch 95
# Score: [9.95679312e-01 9.96088359e-01 9.94079008e-01 4.51840812e-01
#  4.47225090e-03 8.56306473e-03 4.22025691e-01 6.40108746e-04
#  9.12896761e-03]
# Rejected.
# Training model 156
# Good models found: 0
# Training ensemble member 157
# Training finalized at epoch 59
# Score: [0.99082298 0.98942278 0.98773652 0.41794456 0.00653344 0.00508996
#  0.37975657 0.02276648 0.00564458]
# Rejected.
# Training model 157
# Good models found: 0
# Training ensemble member 158
# Training finalized at epoch 92
# Score: [ 9.92796836e-01  9.94541405e-01  9.91314226e-01  4.60262253e-01
#  -1.19848550e-02  6.95449575e-04  4.39143828e-01 -3.53674064e-03
#  -2.10482749e-03]
# Rejected.
# Training model 158
# Good models found: 0
# Training ensemble member 159
# Training finalized at epoch 86
# Score: [ 9.96583547e-01  9.91618823e-01  9.91648431e-01  4.64057705e-01
#  -1.85521398e-03  1.88478376e-03  4.58347273e-01  1.49036175e-04
#   1.03123830e-02]
# Rejected.
# Training model 159
# Good models found: 0
# Training ensemble member 160
# Training finalized at epoch 113
# Score: [0.99638945 0.99819529 0.99442317 0.46510007 0.02282224 0.03125452
#  0.44312191 0.02308625 0.02802933]
# Rejected.
# Training model 160
# Good models found: 0
# Training ensemble member 161
# Training finalized at epoch 117
# Score: [ 9.96223675e-01  9.94716592e-01  9.90755784e-01  4.12364530e-01
#  -3.08130640e-04  5.04914598e-03  4.01741611e-01  3.40115966e-03
#  -7.15270266e-04]
# Rejected.
# Training model 161
# Good models found: 0
# Training ensemble member 162
# Training finalized at epoch 58
# Score: [ 0.99268303  0.9927232   0.98886675  0.47271377  0.00303124  0.00977911
#   0.4440177  -0.00165115  0.00822912]
# Rejected.
# Training model 162
# Good models found: 0
# Training ensemble member 163
# Training finalized at epoch 112
# Score: [0.99752099 0.99731013 0.99275809 0.43974509 0.01282255 0.00778308
#  0.41240787 0.01238316 0.01421905]
# Rejected.
# Training model 163
# Good models found: 0
# Training ensemble member 164
# Training finalized at epoch 138
# Score: [ 0.99598383  0.99694066  0.99235732  0.4679584  -0.0448775  -0.03260902
#   0.45075806 -0.02884456 -0.03287953]
# Rejected.
# Training model 164
# Good models found: 0
# Training ensemble member 165
# Training finalized at epoch 70
# Score: [ 0.98932382  0.97963931  0.98877187  0.41004049 -0.03921219 -0.02591627
#   0.38467249 -0.03928044 -0.02161542]
# Rejected.
# Training model 165
# Good models found: 0
# Training ensemble member 166
# Training finalized at epoch 62
# Score: [0.99618057 0.98633865 0.9888274  0.43958228 0.02550477 0.02402946
#  0.41734017 0.01820666 0.03128119]
# Rejected.
# Training model 166
# Good models found: 0
# Training ensemble member 167
# Training finalized at epoch 110
# Score: [ 0.99702771  0.98673521  0.99320754  0.46046492 -0.02710763 -0.03138854
#   0.44489227 -0.02332252 -0.02329723]
# Rejected.
# Training model 167
# Good models found: 0
# Training ensemble member 168
# Training finalized at epoch 79
# Score: [ 0.99711408  0.99310222  0.99197658  0.45361032 -0.0890419  -0.08911634
#   0.41026495 -0.09567347 -0.09102937]
# Rejected.
# Training model 168
# Good models found: 0
# Training ensemble member 169
# Training finalized at epoch 125
# Score: [0.99851087 0.99785022 0.99366895 0.43713225 0.02697884 0.03126217
#  0.41867501 0.01925446 0.02635871]
# Rejected.
# Training model 169
# Good models found: 0
# Training ensemble member 170
# Training finalized at epoch 87
# Score: [0.99585694 0.98432703 0.99427747 0.44477894 0.02839538 0.03163131
#  0.4270685  0.02660057 0.02633137]
# Rejected.
# Training model 170
# Good models found: 0
# Training ensemble member 171
# Training finalized at epoch 72
# Score: [0.9951037  0.99461239 0.99203495 0.46461916 0.01479946 0.01525562
#  0.44326119 0.01060222 0.02001607]
# Rejected.
# Training model 171
# Good models found: 0
# Training ensemble member 172
# Training finalized at epoch 62
# Score: [ 0.9794078   0.99087934  0.97954711  0.39557686 -0.07915252 -0.04513457
#   0.35991926 -0.02633167 -0.03156713]
# Rejected.
# Training model 172
# Good models found: 0
# Training ensemble member 173
# Training finalized at epoch 57
# Score: [ 0.98717012  0.97252805  0.99004076  0.42426335 -0.05958164 -0.06013017
#   0.40952499 -0.0699138  -0.04222317]
# Rejected.
# Training model 173
# Good models found: 0
# Training ensemble member 174
# Training finalized at epoch 145
# Score: [ 0.99629152  0.9937635   0.99375133  0.4888102  -0.01306883 -0.00572179
#   0.47563944 -0.0142893  -0.00266893]
# Rejected.
# Training model 174
# Good models found: 0
# Training ensemble member 175
# Training finalized at epoch 99
# Score: [ 0.99360548  0.99699103  0.98960532  0.42904234 -0.00682359 -0.00197628
#   0.41186431 -0.01451555  0.00363274]
# Rejected.
# Training model 175
# Good models found: 0
# Training ensemble member 176
# Training finalized at epoch 154
# Score: [ 0.99540453  0.99685489  0.989058    0.42333448 -0.05243414 -0.0623194
#   0.38839039 -0.06197007 -0.05788582]
# Rejected.
# Training model 176
# Good models found: 0
# Training ensemble member 177
# Training finalized at epoch 128
# Score: [ 0.99886678  0.99667387  0.99376533  0.46115159  0.00883578  0.00338824
#   0.42827966 -0.00697758 -0.0034821 ]
# Rejected.
# Training model 177
# Good models found: 0
# Training ensemble member 178
# Training finalized at epoch 72
# Score: [ 0.99690563  0.99230355  0.99211857  0.46964429 -0.01420163  0.00609919
#   0.44663845 -0.01629428 -0.01796839]
# Rejected.
# Training model 178
# Good models found: 0
# Training ensemble member 179
# Training finalized at epoch 122
# Score: [ 0.99755657  0.99616862  0.99269202  0.47937947 -0.02490926 -0.02948018
#   0.47024539 -0.04298357 -0.03706455]
# Rejected.
# Training model 179
# Good models found: 0
# Training ensemble member 180
# Training finalized at epoch 75
# Score: [ 0.99524047  0.99435683  0.99513679  0.47313119 -0.03421287 -0.01086893
#   0.45308099 -0.0269697  -0.01829348]
# Rejected.
# Training model 180
# Good models found: 0
# Training ensemble member 181
# Training finalized at epoch 89
# Score: [0.99383055 0.99391715 0.9833316  0.46780452 0.01190301 0.01661583
#  0.45148851 0.00692953 0.01097145]
# Rejected.
# Training model 181
# Good models found: 0
# Training ensemble member 182
# Training finalized at epoch 118
# Score: [ 0.99499774  0.99665941  0.99316398  0.46432467 -0.01608342 -0.00720411
#   0.44930558 -0.01492666 -0.00425386]
# Rejected.
# Training model 182
# Good models found: 0
# Training ensemble member 183
# Training finalized at epoch 138
# Score: [ 0.99547746  0.9976551   0.99398211  0.477201   -0.01950033 -0.01307292
#   0.45811452 -0.02585214 -0.00740887]
# Rejected.
# Training model 183
# Good models found: 0
# Training ensemble member 184
# Training finalized at epoch 71
# Score: [ 0.99482169  0.99229035  0.98538565  0.47142009 -0.02262424 -0.02126387
#   0.4437229  -0.01916943 -0.01976015]
# Rejected.
# Training model 184
# Good models found: 0
# Training ensemble member 185
# Training finalized at epoch 186
# Score: [0.99947533 0.99602032 0.99392258 0.4673367  0.00847256 0.01687563
#  0.45501994 0.01627872 0.01013631]
# Rejected.
# Training model 185
# Good models found: 0
# Training ensemble member 186
# Training finalized at epoch 118
# Score: [ 0.99878709  0.99793802  0.99350714  0.432112   -0.0082321  -0.00704081
#   0.41366224 -0.00763808 -0.00826008]
# Rejected.
# Training model 186
# Good models found: 0
# Training ensemble member 187
# Training finalized at epoch 100
# Score: [0.9983931  0.9959819  0.99288101 0.4748347  0.02166768 0.02755813
#  0.45690706 0.02632449 0.02781359]
# Rejected.
# Training model 187
# Good models found: 0
# Training ensemble member 188
# Training finalized at epoch 70
# Score: [ 0.99274017  0.99254747  0.98455191  0.44437399 -0.04710265 -0.05827761
#   0.41907275 -0.03973796 -0.03935987]
# Rejected.
# Training model 188
# Good models found: 0
# Training ensemble member 189
# Training finalized at epoch 60
# Score: [0.98896439 0.98215861 0.99032422 0.47910161 0.00227476 0.00896534
#  0.45959062 0.00452208 0.00728615]
# Rejected.
# Training model 189
# Good models found: 0
# Training ensemble member 190
# Training finalized at epoch 81
# Score: [ 0.99266773  0.99308366  0.99195968  0.4908764  -0.08242213 -0.06215341
#   0.45391124 -0.07634056 -0.06143389]
# Rejected.
# Training model 190
# Good models found: 0
# Training ensemble member 191
# Training finalized at epoch 55
# Score: [ 0.97714824  0.99198758  0.9873543   0.44571806 -0.05863575 -0.02049556
#   0.41892529 -0.02904507 -0.02745286]
# Rejected.
# Training model 191
# Good models found: 0
# Training ensemble member 192
# Training finalized at epoch 63
# Score: [ 0.99379905  0.99185326  0.99132922  0.44063131 -0.02445046 -0.02007088
#   0.41261953 -0.02841058 -0.02798517]
# Rejected.
# Training model 192
# Good models found: 0
# Training ensemble member 193
# Training finalized at epoch 68
# Score: [ 0.99448133  0.99318054  0.99053326  0.44142566 -0.04051123 -0.04093295
#   0.42819538 -0.0362304  -0.03424129]
# Rejected.
# Training model 193
# Good models found: 0
# Training ensemble member 194
# Training finalized at epoch 127
# Score: [0.99907337 0.99763304 0.99247077 0.48471281 0.02939548 0.03119882
#  0.46223316 0.03094418 0.03721598]
# Rejected.
# Training model 194
# Good models found: 0
# Training ensemble member 195
# Training finalized at epoch 54
# Score: [ 0.99026548  0.98467455  0.99325032  0.4789068  -0.08266311 -0.05507641
#   0.46429367 -0.0438078  -0.03170396]
# Rejected.
# Training model 195
# Good models found: 0
# Training ensemble member 196
# Training finalized at epoch 74
# Score: [ 9.94573117e-01  9.86291439e-01  9.92181077e-01  4.56446763e-01
#  -4.34708300e-03  7.53704244e-04  4.40217516e-01 -7.22161004e-03
#   9.11618244e-04]
# Rejected.
# Training model 196
# Good models found: 0
# Training ensemble member 197
# Training finalized at epoch 76
# Score: [ 0.99659188  0.99471797  0.99060271  0.44690664 -0.0191487  -0.01021283
#   0.43198739 -0.01759335 -0.00682214]
# Rejected.
# Training model 197
# Good models found: 0
# Training ensemble member 198
# Training finalized at epoch 71
# Score: [ 0.98889559  0.97318747  0.99100244  0.39489904 -0.01323414 -0.01769694
#   0.37318331 -0.03144222 -0.0268416 ]
# Rejected.
# Training model 198
# Good models found: 0
# Training ensemble member 199
# Training finalized at epoch 64
# Score: [ 0.99484878  0.99061135  0.99389529  0.35208351 -0.00230671 -0.0085984
#   0.36610499 -0.00597479 -0.00270624]
# Rejected.
# Training model 199
# Good models found: 0
# Training ensemble member 200
# Training finalized at epoch 69
# Score: [0.99557884 0.97999238 0.99314391 0.44776847 0.01222901 0.02067998
#  0.42467595 0.00564539 0.00916033]
# Rejected.
# Training model 200
# /usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /var/folders/jc/f0qzb85j0p102grvg_s4spsm5jr2zx/T/ipykernel_98223/355155561.py:84: RuntimeWarning: Mean of empty slice.
#   mean = results.mean(axis=0)
# /usr/local/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In [5], line 6
#       2 # import nn_learner
#       4 DB_PATH='SOLEDGE.db'
# ----> 6 model =retrain(db_path=DB_PATH)
#       8 #Ensure model can be pickled and unpickled.
#       9 torch.save(model,"data.pt")
#
# Cell In [4], line 263, in retrain(db_path, learning_config)
#     261 #    full_model = SOLVER_INDEXES( networks, error_info)
#     262     full_model = LearnerModel( networks, error_info)
# --> 263     full_model.calibrate(full_dataset)
#     265     return full_model
#
# Cell In [4], line 99, in Model.calibrate(self, dataset)
#      96 true = dataset[:][-1].numpy()
#      97 abserr = np.abs(pred-true)
# ---> 99 calibration = np.mean(abserr,axis=0)/np.mean(uncertainty,axis=0)
#     101 calibration /= 3
#     102 self.err_info /= calibration
#
# File <__array_function__ internals>:180, in mean(*args, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3430, in mean(a, axis, dtype, out, keepdims, where)
#    3428         pass
#    3429     else:
# -> 3430         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3432 return _methods._mean(a, axis=axis, dtype=dtype,
#    3433                       out=out, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/numpy/core/_methods.py:168, in _mean(a, axis, dtype, out, keepdims, where)
#     164 arr = asanyarray(a)
#     166 is_float16_result = False
# --> 168 rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     169 if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     170     warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# File /usr/local/lib/python3.10/site-packages/numpy/core/_methods.py:76, in _count_reduce_items(arr, axis, keepdims, where)
#      74     items = 1
#      75     for ax in axis:
# ---> 76         items *= arr.shape[mu.normalize_axis_index(ax, arr.ndim)]
#      77     items = nt.intp(items)
#      78 else:
#      79     # TODO: Optimize case when `where` is broadcast along a non-reduction
#      80     # axis and full sum is more excessive than needed.
#      81
#      82     # guarded to protect circular imports
#
# AxisError: axis 0 is out of bounds for array of dimension 0
